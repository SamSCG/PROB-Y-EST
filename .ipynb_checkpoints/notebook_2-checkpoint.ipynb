# %%
import matplotlib.pyplot as plt
print("setup terminado")
# Out:
# setup terminado

# %% [markdown]
# - [indice](index.ipynd)

# %% [markdown]
# #### En este trabajo se analizan 500 datos cuantitativos continuos que representan mediciones de presión arterial sistólica (en mmHg) en adultos. Los datos se agrupan en una tabla de frecuencias y se visualizan mediante gráficas estadísticas para interpretar su comportamiento.

# %% [markdown]
# #### 35.84,  39.01,  37.47,  38.76,  39.9,   37.92,  37.76,  35.82,  36.71,  37.75,  38.56,  39.12,  37.21,  35.8,   36.8,
# #### 39.59,  36.46,  37.53,  39.69,  35.61,  38.2,   39.78,  36.54,  37.97,  39.59,  36.1,   37.86,  38.88,  38.51,  37.6,
# #### 36.42,  37.71,  37.18,  37.65,  37.15,  39.27,  38.96,  36.91,  38.08,  36.74,  37.54,  37.09,  38.46,  37.17,
# #### 37.57,  38.74,  37.36,  39.58,  36.31,  38.84,  37.4,   37.42,  38.35,  37.85,  37.37,  35.51,  35.92,  38.69,
# #### 37.86,  38.63,  39.8,   38.57,  35.74,  36.89,  38.17,  36.56,  39.84,  39.75,  39.32,  37.63,  39.29,  36.09,
# #### 36.8,   35.78,  36.89,  36.99,  36.14,  37.92,  38.41,  38.97,  39.94,  36.84,  35.66,  39.86,  36.03,  38.15,
# #### 38.83,  38.77,  39.96,  35.56,  36.58,  35.66,  35.6,   36.34,  38.65,  39.5,   35.55,  35.86,  39.63,  36.33,

# %% [markdown]
# # Tabla de Datos Cuantitativos Continuos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos (los 500 datos que generamos antes)
np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Definir intervalos: por ejemplo, clases de 0.5 grados de 35.5 a 40.0
intervalos = np.arange(35.5, 40.5, 0.5)

# Crear tabla de frecuencias usando pd.cut y value_counts
categorias = pd.cut(datos, bins=intervalos, right=True, include_lowest=True)

# Frecuencia absoluta
fa = categorias.value_counts().sort_index()

# Frecuencia relativa
fr = fa / fa.sum()

# Frecuencia acumulada
fac = fa.cumsum()

# Frecuencia relativa acumulada
frac = fr.cumsum()

# Crear DataFrame con toda la información
tabla_frecuencias = pd.DataFrame({
    "Intervalo": fa.index.astype(str),
    "Frecuencia Absoluta": fa.values,
    "Frecuencia Relativa": fr.values,
    "Frecuencia Acumulada": fac.values,
    "Frecuencia Relativa Acumulada": frac.values
})

# Ajustar opciones de pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

# Imprimir la tabla de frecuencias
print(tabla_frecuencias)

# Visualizaciones
fig, ax1 = plt.subplots(figsize=(12, 6))

# Colores diferentes para cada barra
colores = plt.cm.viridis(np.linspace(0, 1, len(tabla_frecuencias)))

# Gráfico de barras para la frecuencia absoluta con colores diferentes
ax1.bar(tabla_frecuencias["Intervalo"], tabla_frecuencias["Frecuencia Absoluta"], color=colores, label='Frecuencia Absoluta')
ax1.set_xlabel("Intervalo")
ax1.set_ylabel("Frecuencia Absoluta", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title("Frecuencia Absoluta y Acumulada")

# Crear un segundo eje para la frecuencia acumulada
ax2 = ax1.twinx()
ax2.plot(tabla_frecuencias["Intervalo"], tabla_frecuencias["Frecuencia Acumulada"], color='orange', marker='o', label='Frecuencia Acumulada')
ax2.set_ylabel("Frecuencia Acumulada", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Añadir leyendas
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#         Intervalo  Frecuencia Absoluta  Frecuencia Relativa  Frecuencia Acumulada  Frecuencia Relativa Acumulada
# 0  (35.499, 36.0]                   58                0.116                    58                          0.116
# 1    (36.0, 36.5]                   50                0.100                   108                          0.216
# 2    (36.5, 37.0]                   56                0.112                   164                          0.328
# 3    (37.0, 37.5]                   57                0.114                   221                          0.442
# 4    (37.5, 38.0]                   64                0.128                   285                          0.570
# 5    (38.0, 38.5]                   46                0.092                   331                          0.662
# 6    (38.5, 39.0]                   50                0.100                   381                          0.762
# ...

# %% [markdown]
# ## Histograma

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Definir los bins
bins = np.arange(35.5, 40.5, 0.5)

# Crear histograma y obtener valores para colorear barras
counts, bins_edges, patches = plt.hist(datos, bins=bins, edgecolor='black')

# Colores para las barras, uno diferente para cada barra
colors = plt.cm.viridis(np.linspace(0, 1, len(patches)))

for patch, color in zip(patches, colors):
    patch.set_facecolor(color)

plt.title('Histograma')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frecuencia Absoluta')

plt.show()

# %% [markdown]
# ## Diagrama de Barras Horizontales

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Datos generados
np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Definir intervalos
intervalos = np.arange(35.5, 40.5, 0.5)

# Categorizar datos en intervalos
categorias = pd.cut(datos, bins=intervalos, right=True, include_lowest=True)

# Calcular frecuencia absoluta
fa = categorias.value_counts().sort_index()

# Preparar etiquetas para el eje y (intervalos)
etiquetas = fa.index.astype(str)

# Colores para las barras
colors = plt.cm.plasma(np.linspace(0, 1, len(fa)))

# Crear gráfico de barras horizontales
plt.barh(etiquetas, fa.values, color=colors, edgecolor='black')

plt.xlabel('Frecuencia Absoluta')
plt.ylabel('Intervalo de Temperatura (°C)')
plt.title('Diagrama de Barras Horizontales')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Poligono de Frecuencias

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generar los 500 datos de temperatura
np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Definir los intervalos de clase
intervalos = np.arange(35.5, 40.5, 0.5)
categorias = pd.cut(datos, bins=intervalos, right=True, include_lowest=True)

# Calcular frecuencia relativa
frecuencia_absoluta = categorias.value_counts().sort_index()
frecuencia_relativa = frecuencia_absoluta / frecuencia_absoluta.sum()

# Calcular los puntos medios de cada intervalo
puntos_medios = [(interval.left + interval.right) / 2 for interval in frecuencia_relativa.index]

# Graficar el polígono de frecuencia relativa
plt.plot(puntos_medios, frecuencia_relativa.values, marker='o', linestyle='-', color='blue')

plt.title('Polígono de Frecuencia Relativa')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frecuencia Relativa')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Diagrama de Pastel

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Datos
np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Crear intervalos
intervalos = np.arange(35.5, 40.5, 0.5)
categorias = pd.cut(datos, bins=intervalos, right=True, include_lowest=True)

# Frecuencia relativa
fa = categorias.value_counts().sort_index()
fr = fa / fa.sum()

# Etiquetas
etiquetas = [str(interval) for interval in fr.index]

# Explode para resaltar el porcentaje más alto
explode = [0.1 if i == fr.values.argmax() else 0 for i in range(len(fr))]

# Colores distintos para cada rebanada
colores = plt.cm.tab20(np.linspace(0, 1, len(fr)))

# Crear diagrama de pastel
plt.figure(figsize=(7, 7))
plt.pie(fr, labels=etiquetas, autopct='%1.1f%%', startangle=90,
        colors=colores, explode=explode, shadow=True)

plt.title('Diagrama de Pastel - Frecuencia Relativa')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ojiva

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Datos generados
np.random.seed(7)
datos = np.random.uniform(35.5, 40.0, 500)
datos = np.round(datos, 2)

# Crear intervalos
intervalos = np.arange(35.5, 40.5, 0.5)
categorias = pd.cut(datos, bins=intervalos, right=True, include_lowest=True)

# Frecuencia acumulada
fa = categorias.value_counts().sort_index()
fac = fa.cumsum()

# Limites superiores de cada intervalo (para el eje x)
limites_superiores = [interval.right for interval in fac.index]

# Graficar ojiva
plt.plot(limites_superiores, fac.values, marker='o', linestyle='-', color='green')

plt.title('Ojiva - Frecuencia Acumulada')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frecuencia Acumulada')
plt.grid(True)
plt.tight_layout()
plt.show()
